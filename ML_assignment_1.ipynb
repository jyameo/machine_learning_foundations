# %%
#Learning Pandas & pylab

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas
from pandas import *
from sklearn import datasets, linear_model

# %%
houses = read_csv('home_data.csv')

# %%
houses
# Out:
#             id             date    price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900         3       1.00         1180
# 1   6414100192  20141209T000000   538000         3       2.25         2570
# 2   5631500400  20150225T000000   180000         2       1.00          770
# 3   2487200875  20141209T000000   604000         4       3.00         1960
# 4   1954400510  20150218T000000   510000         3       2.00         1680
# 5   7237550310  20140512T000000  1225000         4       4.50         5420
# 6   1321400060  20140627T000000   257500         3       2.25         1715
# 7   2008000270  20150115T000000   291850         3       1.50         1060
# 8   2414600126  20150415T000000   229500         3       1.00         1780
# 9   3793500160  20150312T000000   323000         3       2.50         1890
# 10  1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %%
exp_houses = houses[houses.zipcode == 98039]

# %%
exp_houses.head()
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 2974  3625049014  20140829T000000  2950000         4        3.5         4860
# 3761  2540700110  20150212T000000  1905000         4        3.5         4210
# 4077  3262300940  20141107T000000   875000         3        1.0         1220
# 4078  3262300940  20150210T000000   940000         3        1.0         1220
# 4149  6447300265  20141014T000000  4000000         4        5.5         7080
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2974     23885       2           0     0          3     12        4860
# 3761     18564       2           0     0          3     11        4210
# 4077      8119       1           0     0          4      7        1220
# 4078      8119       1           0     0          4      7        1220
# 4149     16573       2           0     0          3     12        5760
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
avg_price = exp_houses['price'].mean(axis=1)

# %%
avg_price
# Out:
# 2160606.6000000001

# %%
mask1 = ((houses['sqft_living'] > 2000) & (houses['sqft_living'] <= 4000))

# %%
filter_houses1= houses[mask1]

# %%
filter_houses1
# Out:
#              id             date    price  bedrooms  bathrooms  sqft_living  \
# 1    6414100192  20141209T000000   538000         3       2.25         2570
# 10   1736800520  20150403T000000   662500         3       2.50         3560
# 15   9297300055  20150124T000000   650000         4       3.00         2950
# 21   2524049179  20140826T000000  2000000         3       2.75         3050
# 22   7137970340  20140703T000000   285000         5       2.50         2270
# 24   3814700200  20141120T000000   329000         3       2.25         2450
# 26   1794500383  20140626T000000   937000         3       1.75         2450
# 29   1873100390  20150302T000000   719000         4       2.50         2570
# 30   8562750320  20141110T000000   580500         3       2.50         2320
# 32    461000390  20140624T000000   687500         4       1.75         2330
# 34   7955080270  20141203T000000   322500         4       2.75         2060
# ...

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house
'grade', # measure of quality of construction
'waterfront', # waterfront property
'view', # type of view
'sqft_above', # square feet above ground
'sqft_basement', # square feet in basement
'yr_built', # the year built
'yr_renovated', # the year renovated
'lat', 'long', # the lat-long of the parcel
'sqft_living15', # average sq.ft. of 15 nearest neighbors
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
# Create linear regression object
regr1 = linear_model.LinearRegression()
regr2 = linear_model.LinearRegression()

# %%
splitter = np.random.rand(len(houses)) < 0.8

# %%
train_data = houses[splitter]
test_data = houses[~splitter]

# %%
regr1.fit(train_data[my_features], train_data['price'])
regr2.fit(train_data[advanced_features], train_data['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(regr1.coef_)
print(regr2.coef_)
# Out:
# [ -5.59282350e+04   1.30826235e+04   3.15778138e+02  -3.10334374e-01
#   -3.96946114e+03   5.61059168e+02]
# [ -3.42332478e+04   4.39079698e+04   1.08203673e+02   1.21000987e-01
#    4.06518413e+03  -5.95003743e+02   2.82150447e+04   9.71515268e+04
#    5.66284905e+05   5.16523843e+04   7.26769938e+01   3.55266799e+01
#   -2.63447080e+03   1.39890196e+01   6.07444336e+05  -2.30855933e+05
#    2.32553731e+01  -3.94340192e-01]

# %%
print("RMSE: %.2f"
      % np.sqrt(np.mean(regr1.predict(test_data[my_features])  - test_data['price'] ) ** 2))

print("RMSE_adv: %.2f"
      % np.sqrt(np.mean(regr2.predict(test_data[advanced_features]) - test_data['price']) ** 2))
# Out:
# RMSE: 3528.58
# RMSE_adv: 5185.98

# %%
print(test_data['price'][0:2])
print(regr1.predict(test_data[my_features])[0:2])
print(regr2.predict(test_data[advanced_features])[0:2])
# Out:
# 0     221900
# 5    1225000
# Name: price, dtype: int64
# [  323819.13361875  1552567.99549939]
# [  207529.76225407  1461923.64028598]
