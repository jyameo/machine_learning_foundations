# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas
from pandas import *
from sklearn import datasets, linear_model
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# %%
reviews = read_csv('amazon_baby.csv')

# %%
reviews
# Out:
#                                                  name  \
# 0                            Planetwise Flannel Wipes
# 1                               Planetwise Wipe Pouch
# 2                 Annas Dream Full Quilt with 2 Shams
# 3   Stop Pacifier Sucking without tears with Thumb...
# 4   Stop Pacifier Sucking without tears with Thumb...
# 5   Stop Pacifier Sucking without tears with Thumb...
# 6            A Tale of Baby\'s Days with Peter Rabbit
# 7   Baby Tracker&reg; - Daily Childcare Journal, S...
# 8   Baby Tracker&reg; - Daily Childcare Journal, S...
# 9   Baby Tracker&reg; - Daily Childcare Journal, S...
# 10  Baby Tracker&reg; - Daily Childcare Journal, S...
# 11  Baby Tracker&reg; - Daily Childcare Journal, S...
# 12  Baby Tracker&reg; - Daily Childcare Journal, S...
# 13  Baby Tracker&reg; - Daily Childcare Journal, S...
# 14    Nature\'s Lullabies First Year Sticker Calendar
# 15    Nature\'s Lullabies First Year Sticker Calendar
# 16    Nature\'s Lullabies First Year Sticker Calendar
# 17   Nature\'s Lullabies Second Year Sticker Calendar
# 18   Nature\'s Lullabies Second Year Sticker Calendar
# 19   Nature\'s Lullabies Second Year Sticker Calendar
# 20   Nature\'s Lullabies Second Year Sticker Calendar
# 21   Nature\'s Lullabies Second Year Sticker Calendar
# 22   Nature\'s Lullabies Second Year Sticker Calendar
# 23   Nature\'s Lullabies Second Year Sticker Calendar
# 24   Nature\'s Lullabies Second Year Sticker Calendar
# 25   Nature\'s Lullabies Second Year Sticker Calendar
# 26                      Baby\'s First Journal - Green
# 27                        Lamaze Peekaboo, I Love You
# 28                        Lamaze Peekaboo, I Love You
# 29                        Lamaze Peekaboo, I Love You
# 30                        Lamaze Peekaboo, I Love You
# 31                        Lamaze Peekaboo, I Love You
# 32                        Lamaze Peekaboo, I Love You
# 33                        Lamaze Peekaboo, I Love You
# 34                        Lamaze Peekaboo, I Love You
# 35                        Lamaze Peekaboo, I Love You
# 36                        Lamaze Peekaboo, I Love You
# 37                        Lamaze Peekaboo, I Love You
# 38       SoftPlay Twinkle Twinkle Elmo A Bedtime Book
# 39       SoftPlay Twinkle Twinkle Elmo A Bedtime Book
# 40       SoftPlay Twinkle Twinkle Elmo A Bedtime Book
# 41         SoftPlay Giggle Jiggle Funbook, Happy Bear
# 42  SoftPlay Peek-A-Boo Where\'s Elmo A Children\'...
# 43  SoftPlay Peek-A-Boo Where\'s Elmo A Children\'...
# 44  SoftPlay Peek-A-Boo Where\'s Elmo A Children\'...
# 45  SoftPlay Peek-A-Boo Where\'s Elmo A Children\'...
# 46  SoftPlay Peek-A-Boo Where\'s Elmo A Children\'...
# 47  SoftPlay Peek-A-Boo Where\'s Elmo A Children\'...
# 48           SoftPlay 4 Pack Block Book, Sweet Sesame
# 49           SoftPlay 4 Pack Block Book, Sweet Sesame
# 50                          SoftPlay Cloth Book, Love
# 51        SoftPlay Baby\'s First Cloth Books Gift Set
# 52                          SoftPlay Cloth Book, Hugs
# 53  SoftPlay Baby Animals of the World Soft Cloth ...
# 54  Baby\'s First Year Undated Wall Calendar with ...
# 55  Baby\'s First Year Undated Wall Calendar with ...
# 56  Baby\'s First Year Undated Wall Calendar with ...
# 57  Baby\'s First Year Undated Wall Calendar with ...
# 58                          Our Baby Girl Memory Book
# 59                          Our Baby Girl Memory Book
#                                                   ...
#
#                                                review  rating
# 0   These flannel wipes are OK, but in my opinion ...       3
# 1   it came early and was not disappointed. i love...       5
# 2   Very soft and comfortable and warmer than it l...       5
# 3   This is a product well worth the purchase.  I ...       5
# 4   All of my kids have cried non-stop when I trie...       5
# 5   When the Binky Fairy came to our house, we did...       5
# 6   Lovely book, it\'s bound tightly so you may no...       4
# 7   Perfect for new parents. We were able to keep ...       5
# 8   A friend of mine pinned this product on Pinter...       5
# 9   This has been an easy way for my nanny to reco...       4
# 10  I love this journal and our nanny uses it ever...       4
# 11  This book is perfect!  I\'m a first time new m...       5
# 12  I originally just gave the nanny a pad of pape...       4
# 13  I thought keeping a simple handwritten journal...       3
# 14  Space for monthly photos, info and a lot of us...       5
# 15  I bought this calender for myself for my secon...       4
# 16  I love this little calender, you can keep trac...       5
# 17  This was the only calender I could find for th...       5
# 18  I completed a calendar for my son\'s first yea...       4
# 19  We wanted to get something to keep track of ou...       5
# 20  I had a hard time finding a second year calend...       5
# 21  I only purchased a second-year calendar for my...       2
# 22  I LOVE this calendar for recording events of m...       5
# 23  Calendar is exactly as described, but I find t...       3
# 24  Wife loves this calender. Comes with a lot of ...       5
# 25  My daughter had her 1st baby over a year ago. ...       5
# 26  Extremely useful! As a new mom, tired and inex...       5
# 27  My son loves peek a boo at this age of 9 month...       3
# 28  One of baby\'s first and favorite books, and i...       4
# 29  I like how the book has a hook to attach it to...       5
# 30  Beautiful little book.  A great little short s...       5
# 31  This book is so worth the money. It says 9+ mo...       5
# 32  we just got this book for our one-year-old and...       5
# 33  The book is colorful and is perfect for 6month...       4
# 34  The book is cute, and we are huge fans of Lama...       3
# 35  What a great book for babies!  I\'d been looki...       5
# 36  My son loved this book as an infant.  It was p...       5
# 37  Our baby loves this book & has loved it for a ...       5
# 38                                                NaN       5
# 39  My son likes brushing elmo\'s teeth. Almost to...       5
# 40  This was a birthday present for my 2 year old ...       5
# 41  This bear is absolutely adorable and I would g...       2
# 42  My baby absolutely loves Elmo and so this book...       5
# 43  I bought two for recent baby showers!  The boo...       5
# 44  We wanted to get another book like the Big Bir...       4
# 45  This is a cute little peek-a-boo story book.  ...       4
# 46  My 3 month old son loves this book. We read it...       5
# 47  Very cute interactive book! My son loves this ...       5
# 48  Bought for granddauchildren and they play with...       5
# 49  I have teething babies and these were great fo...       4
# 50  This book is boring. Nothing to stimulate my g...       1
# 51  It is so hard to find cloth books with ACTUAL ...       5
# 52  for the young child, very cute...so happy they...       5
# 53  not bad but not as interesting to my 1-year ol...       3
# 54  A friend bought me this calendar when our daug...       5
# 55  Quick and Easy to keep up with all the first m...       5
# 56  I searched high and low for a first year calen...       5
# 57  This is a very good gift for a new mother.  Yo...       5
# 58                                                NaN       5
# 59  Absolutely love it and all of the Scripture in...       5
#                                                   ...     ...
#
# [183531 rows x 3 columns]

# %%
selected_words = ['awesome', 'great', 'fantastic', 'amazing', 'love', 'horrible', 'bad', 'terrible', 'awful', 'wow', 'hate']

# %%
rev = reviews['review']

# %%
list_words = np.array((rev.value_counts)
# Out:
#   File "<ipython-input-16-1e79e1e7ec21>", line 1
#     list_words = np.array((rev.value_counts)
#                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
list_words
# Out:
# array([ 'These flannel wipes are OK, but in my opinion not worth keeping.  I also ordered someImse Vimse Cloth Wipes-Ocean Blue-12 countwhich are larger, had a nicer, softer texture and just seemed higher quality.  I use cloth wipes for hands and faces and have been usingThirsties 6 Pack Fab Wipes, Boyfor about 8 months now and need to replace them because they are starting to get rough and have had stink issues for a while that stripping no longer handles.',
#        'it came early and was not disappointed. i love planet wise bags and now my wipe holder. it keps my osocozy wipes moist and does not leak. highly recommend it.',
#        'Very soft and comfortable and warmer than it looks...fit the full size bed perfectly...would recommend to anyone looking for this type of quilt',
#        ...,
#        'This item looks great and cool for my kids....I know this Company and its great in quality...',
#        'I am extremely happy with this product. I have been searching for a product like this for a long time and just not found the right one. I am a mum who is very into my organic products and unllike many others I have looked at, The Tutti Bimbi Freezer Tray is also BPA and phthalates free. The bright packaging and the ability to choose my colour attracted me to the listing and the fact that I can prepare 9 meals with a very generous portion size for my baby at one time is a massive advantage to me as a working mum. I can freeze the tray easily as it comes with a very easy clip on lid that also protects from freezer burn. I have found I can also put the baby food tray in the dishwasher fine. I would strongly recommend the Tutti Bimbi Baby Food Freezer Tray to any parent like myself who is looking for an easy way to make baby weaning food at home.',
#        'I love this product very mush . I have bought many car shades earlier but they never protected me from direct sun exposure . But these really work well and It also Keeps the temperature of the car'], dtype=object)

# %%
count_vect = CountVectorizer(vocabulary=selected_words)

# %%
word_count = count_vect.fit_transform(list_words)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d7c2db552628> in <module>()
# ----> 1 word_count = count_vect.fit_transform(list_words)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#     815
#     816         vocabulary, X = self._count_vocab(raw_documents,
# --> 817                                           self.fixed_vocabulary_)
#     818
#     819         if self.binary:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     750         indptr.append(0)
#     751         for doc in raw_documents:
# --> 752             for feature in analyze(doc):
#     753                 try:
#     754                     j_indices.append(vocabulary[feature])
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in <lambda>(doc)
#     236
#     237             return lambda doc: self._word_ngrams(
# --> 238                 tokenize(preprocess(self.decode(doc))), stop_words)
#     239
#     240         else:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in decode(self, doc)
#     116
#     117         if doc is np.nan:
# --> 118             raise ValueError("np.nan is an invalid document, expected byte or "
#     119                              "unicode string.")
#     120
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.
